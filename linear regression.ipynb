# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
tr1_mod=pd.read_csv('train_clean.csv')
tr1_mod.head()
# Out:
#    data1  data2  data3  data4  data5  data6  data7  data8  output  data9_F  \
# 0      8    279      2  14.45   1139      1   9.30      1   86.11        0
# 1      1    108      7  14.21   1656      1   7.22      0   42.61        0
# 2      8    258      0  19.22   2817      1   8.73      1   85.63        0
# 3      4    147      0  15.75   1948      1   6.08      1   53.66        0
# 4      5    230      7  10.20   1336      1   4.75      0   64.93        0
#
#    data9_M  data10_p
# 0        1         1
# 1        1         1
# 2        1         1
# 3        1         1
# 4        1         1

# %%
ts1_mod=pd.read_csv('test_clean.csv')
ts1_mod.head()
# Out:
#    data1  data2  data3  data4  data5  data6  data7  data8  data9_F  data9_M  \
# 0      7    195      0  29.04   2725      1   9.30      2        0        1
# 1      9    109      5  20.22   1184      1   7.22      2        0        1
# 2      0    126      2  26.48   2975      1   8.73      1        0        1
# 3      2    209      4  13.45   1067      1   6.08      0        0        1
# 4      5    268      1  25.07   1336      1   4.75      1        0        1
#
#    data10_p
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
#drop all categorical feature
#cat_feat=["data1","data2","data3","data6","data8","data9_M","data9_F","data10_p"]
#tr1_mod.drop(cat_feat,axis=1,inplace=True)
#tr1_mod.head()

# %%
import matplotlib.pyplot as plt
tr1_mod.plot(kind='scatter',x='data4',y='output')
plt.show()

# %%
import matplotlib.pyplot as plt
tr1_mod.plot(kind='scatter',x='data5',y='output')
plt.show()

# %%
import matplotlib.pyplot as plt
tr1_mod.plot(kind='scatter',x='data7',y='output')
plt.show()

# %%
tr1_mod.corr()
# Out:
#              data1     data2     data3     data4     data5     data6  \
# data1     1.000000  0.008089  0.013499  0.000256 -0.017268 -0.009846
# data2     0.008089  1.000000 -0.001394  0.019032  0.017336  0.010257
# data3     0.013499 -0.001394  1.000000  0.014717  0.001663 -0.020772
# data4     0.000256  0.019032  0.014717  1.000000  0.006341  0.000411
# data5    -0.017268  0.017336  0.001663  0.006341  1.000000  0.005788
# data6    -0.009846  0.010257 -0.020772  0.000411  0.005788  1.000000
# data7     0.001910 -0.013158 -0.007163  0.018215  0.009468 -0.020130
# data8    -0.001804  0.013562 -0.008453 -0.003126  0.009289 -0.001732
# output    0.221543  0.867913  0.007231  0.406071  0.015307 -0.009842
# data9_F   0.007309 -0.019469  0.026479 -0.000034 -0.006620 -0.816007
# data9_M  -0.006990  0.019620 -0.026789  0.000275  0.006621  0.816177
# data10_p  0.015640  0.007450 -0.015205  0.011813  0.000017  0.009995
#
# ...

# %%
import matplotlib.pyplot as plt
tr1_mod.plot(kind='scatter',x='data2',y='output')
plt.show()

# %%
import matplotlib.pyplot as plt
tr1_mod.plot(kind='scatter',x='data1',y='output')
plt.show()

# %%
tr1_mod.head()
# Out:
#    data1  data2  data3  data4  data5  data6  data7  data8  output  data9_F  \
# 0      8    279      2  14.45   1139      1   9.30      1   86.11        0
# 1      1    108      7  14.21   1656      1   7.22      0   42.61        0
# 2      8    258      0  19.22   2817      1   8.73      1   85.63        0
# 3      4    147      0  15.75   1948      1   6.08      1   53.66        0
# 4      5    230      7  10.20   1336      1   4.75      0   64.93        0
#
#    data9_M  data10_p
# 0        1         1
# 1        1         1
# 2        1         1
# 3        1         1
# 4        1         1

# %%
#drop all categorical feature
#cat_feat=["data1","data3","data5","data6","data8","data9_M","data9_F","data10_p"]
#tr1_mod.drop(cat_feat,axis=1,inplace=True)
#tr1_mod.head()

# %%
#da2=pd.DataFrame(tr1_mod['data2'])
#da4=pd.DataFrame(tr1_mod['data4'])
#da5=pd.DataFrame(tr1_mod['data5'])
#da7=pd.DataFrame(tr1_mod['data7'])
#op=pd.DataFrame(tr1_mod['output'])

# %%
#da2.head()

# %%
#op.head()

# %%
#da7.head()

# %%
#lm=linear_model.LinearRegression()
#model=lm.fit(da7,op)

# %%
#model.coef_

# %%
#model.intercept_

# %%
#model.score(da7,op)

# %%
ts1_mod.head()
# Out:
#    data1  data2  data3  data4  data5  data6  data7  data8  data9_F  data9_M  \
# 0      7    195      0  29.04   2725      1   9.30      2        0        1
# 1      9    109      5  20.22   1184      1   7.22      2        0        1
# 2      0    126      2  26.48   2975      1   8.73      1        0        1
# 3      2    209      4  13.45   1067      1   6.08      0        0        1
# 4      5    268      1  25.07   1336      1   4.75      1        0        1
#
#    data10_p
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
X_train = tr1_mod.drop(['output'], axis = 1, inplace = False)
y_train = tr1_mod['output']

# %%
X_train.head()
# Out:
#    data1  data2  data3  data4  data5  data6  data7  data8  data9_F  data9_M  \
# 0      8    279      2  14.45   1139      1   9.30      1        0        1
# 1      1    108      7  14.21   1656      1   7.22      0        0        1
# 2      8    258      0  19.22   2817      1   8.73      1        0        1
# 3      4    147      0  15.75   1948      1   6.08      1        0        1
# 4      5    230      7  10.20   1336      1   4.75      0        0        1
#
#    data10_p
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
y_train.head()
# Out:
# 0    86.11
# 1    42.61
# 2    85.63
# 3    53.66
# 4    64.93
# Name: output, dtype: float64

# %%
#drop all categorical feature
#cat_feat=["data1","data3","data5","data6","data8","data9_M","data9_F","data10_p"]
#ts1_mod.drop(cat_feat,axis=1,inplace=True)
#ts1_mod.head()

# %%
X_test=ts1_mod
X_test.head()
# Out:
#    data1  data2  data3  data4  data5  data6  data7  data8  data9_F  data9_M  \
# 0      7    195      0  29.04   2725      1   9.30      2        0        1
# 1      9    109      5  20.22   1184      1   7.22      2        0        1
# 2      0    126      2  26.48   2975      1   8.73      1        0        1
# 3      2    209      4  13.45   1067      1   6.08      0        0        1
# 4      5    268      1  25.07   1336      1   4.75      1        0        1
#
#    data10_p
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
MLR = LinearRegression()
MLR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Print the constant and coeffcients
print(f'constant = {MLR.intercept_}')
print(f'coefficients = {MLR.coef_}')
# Out:
# constant = 19.46428365658445
# coefficients = [ 9.99517716e-01  2.00023963e-01  4.68126197e-03  8.91067588e-01
#  -7.87309356e-06 -7.44489223e-03  1.00323967e+00  4.18124059e-03
#  -6.17023130e+00 -6.56964782e+00 -1.27398791e+01]

# %%
# Predicting the Test set results
y_predict = MLR.predict(X_test)

# %%
# Display actual and predicted values side by side
df = pd.DataFrame( columns=['y_test'])
df['y_predict'] = y_predict
df
# Out:
#      y_test  y_predict
# 0       NaN  81.342249
# 1       NaN  56.228807
# 2       NaN  57.694205
# 3       NaN  62.046236
# 4       NaN  85.854119
# ...     ...        ...
# 9995    NaN  87.265795
# 9996    NaN  90.421088
# 9997    NaN  65.109673
# 9998    NaN  85.527173
# 9999    NaN  88.598386
#
# [10000 rows x 2 columns]

# %%
df.pop('y_test')
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 9995    NaN
# 9996    NaN
# 9997    NaN
# 9998    NaN
# 9999    NaN
# Name: y_test, Length: 10000, dtype: object

# %%
df
# Out:
#       y_predict
# 0     81.342249
# 1     56.228807
# 2     57.694205
# 3     62.046236
# 4     85.854119
# ...         ...
# 9995  87.265795
# 9996  90.421088
# 9997  65.109673
# 9998  85.527173
# 9999  88.598386
#
# [10000 rows x 1 columns]

# %%
final_test=pd.concat([X_test,df], axis = 1)

# %%
final_test
# Out:
#       data1  data2  data3  data4  data5  data6  data7  data8  data9_F  \
# 0         7    195      0  29.04   2725      1   9.30      2        0
# 1         9    109      5  20.22   1184      1   7.22      2        0
# 2         0    126      2  26.48   2975      1   8.73      1        0
# 3         2    209      4  13.45   1067      1   6.08      0        0
# 4         5    268      1  25.07   1336      1   4.75      1        0
# ...     ...    ...    ...    ...    ...    ...    ...    ...      ...
# 9995      7    251      3  23.00   1637      0   8.98      1        1
# 9996      5    275      0  29.51   2339      0   3.57      1        1
# 9997      8    168      2  22.52   1827      0   2.88      1        1
# 9998      4    296      4  16.56   1748      0   6.98      1        1
# 9999      7    281      2  18.55   1651      0   8.28      2        1
#
#       data9_M  data10_p  y_predict
# 0           1         1  81.342249
# 1           1         1  56.228807
# ...
